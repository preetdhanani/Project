# %%
pip install -r requirement.txt
# Out:
# ...
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 50.7/50.7 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/810.5 kB ? eta -:--:--
#    ----------- ---------------------------- 225.3/810.5 kB 4.7 MB/s eta 0:00:01
#    ------------------------ --------------- 491.5/810.5 kB 5.2 MB/s eta 0:00:01
#    -------------------------------- ------- 655.4/810.5 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 810.5/810.5 kB 4.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/269.1 kB ? eta -:--:--
#    ------------------------------ --------- 204.8/269.1 kB 4.2 MB/s eta 0:00:01
# ...
